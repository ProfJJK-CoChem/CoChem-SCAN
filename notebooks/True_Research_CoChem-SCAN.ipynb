# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN")
tests_dir = module_dir / "tests"

print(f"[CoChem-SCAN] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-SCAN.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-SCAN] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN
# plugins: anyio-4.10.0
# collecting ... collected 28 items
#
# tests/test_active.py::test_active_learning_epistemic_variance PASSED     [  3%]
# tests/test_active.py::test_retier_candidates_promotion PASSED            [  7%]
# tests/test_active.py::test_full_active_iteration PASSED                  [ 10%]
# tests/test_active.py::test_active_learning_3d_coordinates_flattening PASSED [ 14%]
# tests/test_compute.py::test_build_orca_input_5_threshold_geom_block PASSED [ 17%]
# tests/test_compute.py::test_build_orca_input_strips_passed_opt_templates PASSED [ 21%]
# tests/test_compute.py::test_parse_orca_out_provenance_tag PASSED         [ 25%]
# tests/test_compute.py::test_apply_active_retiering PASSED                [ 28%]
# tests/test_construct.py::test_build_fragment_library PASSED              [ 32%]
# tests/test_construct.py::test_isolate_and_embed_benzene PASSED           [ 35%]
# tests/test_construct.py::test_generate_candidate_ensemble PASSED         [ 39%]
# tests/test_construct.py::test_interpolate_pes_grid PASSED                [ 42%]
# tests/test_construct.py::test_interpolate_pes_grid_with_pes_store PASSED [ 46%]
# tests/test_critic.py::test_vectorized_broadening_normalization PASSED    [ 50%]
# tests/test_critic.py::test_check_dead_zone_violations PASSED             [ 53%]
# tests/test_critic.py::test_pareto_front_calculation PASSED               [ 57%]
# tests/test_critic.py::test_method_scaling_factor PASSED                  [ 60%]
# tests/test_critic.py::test_evaluate_spectral_critic_escalation PASSED    [ 64%]
# tests/test_ingest.py::test_pre_flight_check PASSED                       [ 67%]
# tests/test_ingest.py::test_map_dead_zones PASSED                         [ 71%]
# tests/test_ingest.py::test_missing_spectrum_file_raises PASSED           [ 75%]
# tests/test_ingest.py::test_pes_store_full_interface PASSED               [ 78%]
# tests/test_ingest.py::test_pes_store_empty_array_saving PASSED           [ 82%]
# tests/test_ingest.py::test_pes_store_dimension_validation PASSED         [ 85%]
# tests/test_ingest.py::test_pes_store_concurrency_safety PASSED           [ 89%]
# tests/test_report.py::test_sanitize_latex PASSED                         [ 92%]
# tests/test_report.py::test_generate_yaml_summary PASSED                  [ 96%]
# tests/test_report.py::test_archive_discarded_branches PASSED             [100%]
#
# ============================= 28 passed in 1.12s ==============================
#
# ✅ Genuine Native Execution Complete.
